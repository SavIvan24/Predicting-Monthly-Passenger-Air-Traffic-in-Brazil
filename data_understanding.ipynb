# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## 1. Collect initial data
#
# Data source: https://www.kaggle.com/datasets/sturarods/anac-national-civil-aviation-agency-2000-2025?select=anac_brazil.csv

# %% [markdown]
# ## 2. Describe data
#
# ### Main features
#
# - Number of data sources: 1
# - Format of the data: csv file
# - Size of the data: 17833 MiB
# - Quantity of the data:
#     - number of records: 22.1M
#     - number of columns: 111
# - Period of the data collection: 2000-2025

# %% [markdown]
# ### Columns description
#
# 1. **id_basica**: Numeric code identifier of the basic step in the system.
# 2. **id_empresa**: no description
# 3. **sg_empresa_icao**: ICAO acronym of the airline. It refers to the designator of the air transport company obtained from the ICAO (International Civil Aviation Organization).
# 4. **sg_empresa_iata**: IATA acronym of the airline. Refers to the designator of the air transport company obtained from IATA (International Air Transport Association).
# 5. **nm_empresa**: Name of the airline.
# 6. **nm_pais**: Name of the country of the nationality of the airline.
# 7. **ds_tipo_empresa**: Description of the type of company. It refers to the description of the type of company in relation to the service performed. It may contain the following descriptions. This variable is in disuse.
# 8. **nr_voo**: no description
# 9. **nr_singular**: Flight Singularity. It refers to the set of characters that helps in the identification of the flight, composed of letters and numbers chosen at the discretion of the airline itself.
# 10. **id_di**: Numerical code that references the identifier digit variable in the system.
# 11. **cd_di**: Identifier Digit. It refers to the character used to identify the type of authorization for each flight stage.
# 12. **ds_di**: Description DI. Presents the description corresponding to the Identifier Digit.
# 13. **ds_grupo_di**: Description of the DI group or Flight Type. Refers to the grouping of DI classifications into types of operations.
# 14. **dt_referencia**: Reference Date. Corresponds to the Expected Start Date of the Flight.
# 15. **nr_ano_referencia**: Reference Year.
# 16. **nr_semestre_referencia**: Reference semester number.
# 17. **nm_semestre_referencia**: Name of the reference semester.
# 18. **nr_trimestre_referencia**: Reference quarter number.
# 19. **nm_trimestre_referencia**: Name of the reference quarter.
# 20. **nr_mes_referencia**: Reference month number.
# 21. **nm_mes_referencia**: Name of the reference month.
# 22. **nr_semana_referencia**: Reference week number.
# 23. **nm_dia_semana_referencia**: Name of the reference week day.
# 24. **nr_dia_referencia**: Reference day number.
# 25. **nr_ano_mes_referencia**: Number representing the year and month of reference, in the format YYYYMM.
# 26. **id_tipo_linha**: Numerical code identifier of the line type in the system.
# 27. **cd_tipo_linha**: Character that identifies the type of line.
# 28. **ds_tipo_linha**: Description of the line type.
# 29. **ds_natureza_tipo_linha**: Description of the nature referring to the type of line (International/Domestic). Consider the nature of the flight, not just the stage.
# 30. **ds_servico_tipo_linha**: Description of the service referring to the type of line (Passenger/Cargo).
# 31. **ds_natureza_etapa**: Description of the nature of the flight stage (International/Domestic).
# 32. **hr_partida_real**: Flight departure time, calculated by the criterion of the calço and descalço.
# 33. **dt_partida_real**: Date of realization. It refers to the full take-off date of the stage, calculated by the criterion of the shoe and barefoot.
# 34. **nr_ano_partida_real**: Number of the actual departure year.
# 35. **nr_semestre_partida_real**: Real departure semester number.
# 36. **nm_semestre_partida_real**: Name of the real departure semester.
# 37. **nr_trimestre_partida_real**: Number of the actual departure quarter.
# 38. **nm_trimestre_partida_real**: Name of the actual departure quarter.
# 39. **nr_mes_partida_real**: Number of the real departure month.
# 40. **nm_mes_partida_real**: Name of the real departure month.
# 41. **nr_semana_partida_real**: Number of the actual departure week.
# 42. **nm_dia_semana_partida_real**: Name of the day of the real departure week.
# 43. **nr_dia_partida_real**: Number of the actual departure day.
# 44. **nr_ano_mes_partida_real**: Number that represents the year and the month of actual departure, in the format YYYYMM.
# 45. **id_aerodromo_origem**: Identifier code of the airfield of origin in the system.
# 46. **sg_icao_origem**: ICAO acronym of the aerodrome of origin.
# 47. **sg_iata_origem**: IATA acronym of the airfield of origin.
# 48. **nm_aerodromo_origem**: Name of the aerodrome of origin.
# 49. **nm_municipio_origem**: Name of the municipality of origin.
# 50. **sg_uf_origem**: Acronym of the Federative Unit of origin.
# 51. **nm_regiao_origem**: Name of the region of origin.
# 52. **nm_pais_origem**: Name of the country of origin.
# 53. **nm_continente_origem**: Name of the continent of origin.
# 54. **nr_etapa**: Step number. Indicates the sequence of the aerodrome of origin between the aerodromes under the same flight number.
# 55. **hr_chegada_real**: Flight arrival time, determined by the criteria of the calço and descalço.
# 56. **dt_chegada_real**: Actual date of arrival.
# 57. **nr_ano_chegada_real**: Number of the year of actual arrival.
# 58. **nr_semestre_chegada_real**: Real arrival semester number.
# 59. **nm_semestre_chegada_real**: Name of the real arrival semester.
# 60. **nr_trimestre_chegada_real**: Number of the actual arrival quarter.
# 61. **nm_trimestre_chegada_real**: Name of the real arrival quarter.
# 62. **nr_mes_chegada_real**: Number of the real month of arrival.
# 63. **nm_mes_chegada_real**: Name of the real month of arrival.
# 64. **nr_semana_chegada_real**: Number of the actual arrival week.
# 65. **nm_dia_semana_chegada_real**: Name of the day of the week of actual arrival.
# 66. **nr_dia_chegada_real**: Number of the actual day of arrival.
# 67. **nr_ano_mes_chegada_real**: Number that represents the year and month of actual arrival, in the format YYYYMM.
# 68. **id_equipamento**: Identification code of the aircraft model in the system.
# 69. **sg_equipamento_icao**: ICAO Designator of the aircraft model ("Type Designator").
# 70. **ds_modelo**: Description of the aircraft model.
# 71. **ds_matricula**: Aircraft registration mark.
# 72. **id_aerodromo_destino**: Identification code of the destination aerodrome in the system.
# 73. **sg_icao_destino**: ICAO acronym of the destination airfield.
# 74. **sg_iata_destino**: IATA acronym of the destination aerodrome.
# 75. **nm_aerodromo_destino**: Name of the destination aerodrome.
# 76. **nm_municipio_destino**: Name of the destination municipality.
# 77. **sg_uf_destino**: Acronym of the destination Federative Unit.
# 78. **nm_regiao_destino**: Name of the destination region.
# 79. **nm_pais_destino**: Name of the destination country.
# 80. **nm_continente_destino**: Name of the destination continent.
# 81. **nr_escala_destino**: Destination scale sequence. It is the number corresponding to the destination aerodrome of the stage, considering the sequential numbering of the aerodromes traveled under the same flight.
# 82. **lt_combustivel**: Amount of fuel consumed, expressed in liters.
# 83. **nr_assentos_ofertados**: Number of seats available at the flight stage.
# 84. **kg_payload**: Payload capacity, expressed in kilograms.
# 85. **km_distancia**: Distance, expressed in kilometers, between the aerodromes of origin and destination of the stage, considering the curvature of planet earth.
# 86. **nr_passag_pagos**: Number of passengers who occupy seats marketed to the public and who generate revenue, with the purchase of seats, for the air transport company.
# 87. **nr_passag_gratis**: Number of passengers who occupy seats marketed to the public, but do not generate revenue, with the purchase of seats, for the air transport company.
# 88. **kg_bagagem_livre**: Franchised baggage. It is all baggage that is not considered as excess, expressed in kilograms.
# 89. **kg_bagagem_excesso**: Excess baggage. It is the total amount of baggage that exceeds the weight limit agreed between the airline and the passenger, checked at the time of dispatch, expressed in kilograms.
# 90. **kg_carga_paga**: Cargo paid. It is the total amount, expressed in kilograms, of all goods that have been transported on the aircraft, except mail and luggage, and have generated direct or indirect revenue for the airline.
# 91. **kg_carga_gratis**: Total quantity, expressed in kilograms, of all goods that have been transported on the aircraft, except mail and baggage, and have not generated direct or indirect revenues for the airline.
# 92. **kg_correio**: Quantity, expressed in kilograms, of objects transported to serve the operators officially designated by the country to operate postal services and comply with the associated obligations arising from the Acts of the Universal Postal Union (UPU).
# 93. **nr_decolagem**: Number of takeoffs.
# 94. **nr_horas_voadas**: Number of hours flown.
# 95. **kg_peso**: Refers to the total weight loaded by the aircraft, calculated by the sum of cargo, mail, passengers and luggage, expressed in kg.
# 96. **nr_velocidade_media**: Average flight speed, calculated from the distance and duration of the flight, expressed in km/h.
# 97. **nr_pax_gratis_km**: Represents, for each basic step, the product between the number of free passengers and the distance of the stage.
# 98. **nr_carga_paga_km**: Refers to the product between the amount of load paid (kg) and the distance of the basic step (km).
# 99. **nr_carga_gratis_km**: Refers to the product between the amount of free load (kg) and the distance of the basic step (km).
# 100. **nr_correio_km**: Refers to the product between the amount of mail (kg) and the distance of the basic step (km).
# 101. **nr_bagagem_paga_km**: Refers to the product between the amount of baggage paid (kg) and the distance of the basic step (km).
# 102. **nr_bagagem_gratis_km**: Refers to the product between the amount of free baggage (kg) and the distance from the basic step (km).
# 103. **nr_ask**: Refers to the volume of Seat Kilometers Offered (Available Seat Kilometer). It is calculated, in each basic step, by the product between the number of seats offered and the distance of the stage.
# 104. **nr_rpk**: Refers to the volume of Passenger Kilometers Transported (Revenue Passenger Kilometer). It is calculated, in each basic step, by the product between the number of passengers paid and the distance of the stage.
# 105. **nr_atk**: Refers to the volume of Tons Kilometers Offered (Available Tonne Kilometer), expressed in (ton x km). It is calculated, in each basic step, by the product between the Payload Capacity (kg) and the distance of the step, divided by 1000.
# 106. **nr_rtk**: Refers to the volume of Tonnes Transported Kilometers (Revenue Tonne Kilometer), expressed in (ton x km). It is calculated, in each basic step, by the product between the quantity, expressed in kilograms, of passengers, luggage, cargo and mail paid transported and the distance of the stage, divided by 1000.
# 107. **id_arquivo**: Identifier code of the data file sent to the system.
# 108. **nm_arquivo**: File name sent to the system.
# 109. **nr_linha**: File line number in which the data of each basic step are contained.
# 110. **dt_sistema**: Date on which the information was recorded in the system.
# 111. **nr_chave**: no description

# %% [markdown]
# ### Sample data

# %%
import pandas as pd

df = pd.read_csv('anac_brazil.csv', nrows = 150000)
pd.set_option('display.max_columns', None)
df.head()
# Out:
# C:\Users\kuzzm\AppData\Local\Temp\ipykernel_3944\3336079047.py:3: DtypeWarning: Columns (0: cd_di) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('anac_brazil.csv', nrows = 150000)
#    id_basica  id_empresa sg_empresa_icao sg_empresa_iata  \
# 0  9705464.0     1000909             AZU              AD
# 1  9705140.0     1000909             AZU              AD
# 2  9705149.0     1000909             AZU              AD
# 3  9705563.0     1000909             AZU              AD
# 4  9705565.0     1000909             AZU              AD
#
#                            nm_empresa nm_pais           ds_tipo_empresa  \
# 0  AZUL LINHAS AÉREAS BRASILEIRAS S/A  BRASIL  TRANSPORTE AÉREO REGULAR
# 1  AZUL LINHAS AÉREAS BRASILEIRAS S/A  BRASIL  TRANSPORTE AÉREO REGULAR
# 2  AZUL LINHAS AÉREAS BRASILEIRAS S/A  BRASIL  TRANSPORTE AÉREO REGULAR
# 3  AZUL LINHAS AÉREAS BRASILEIRAS S/A  BRASIL  TRANSPORTE AÉREO REGULAR
# 4  AZUL LINHAS AÉREAS BRASILEIRAS S/A  BRASIL  TRANSPORTE AÉREO REGULAR
#
#    nr_voo  nr_singular  id_di cd_di                       ds_di ds_grupo_di  \
# 0    6956          242      2     0  REGULAR PREVISTO EM HOTRAN     REGULAR
# 1    4202          372      2     0  REGULAR PREVISTO EM HOTRAN     REGULAR
# 2    4027          377      2     0  REGULAR PREVISTO EM HOTRAN     REGULAR
# 3    5050          181      2     0  REGULAR PREVISTO EM HOTRAN     REGULAR
# 4    5051          181      2     0  REGULAR PREVISTO EM HOTRAN     REGULAR
#
#   dt_referencia  nr_ano_referencia  nr_semestre_referencia  \
# 0    2013-08-01               2013                       2
# 1    2013-08-01               2013                       2
# 2    2013-08-01               2013                       2
# 3    2013-08-01               2013                       2
# 4    2013-08-01               2013                       2
#
#   nm_semestre_referencia  nr_trimestre_referencia nm_trimestre_referencia  \
# 0            2º SEMESTRE                        3            3º TRIMESTRE
# 1            2º SEMESTRE                        3            3º TRIMESTRE
# 2            2º SEMESTRE                        3            3º TRIMESTRE
# 3            2º SEMESTRE                        3            3º TRIMESTRE
# 4            2º SEMESTRE                        3            3º TRIMESTRE
#
#    nr_mes_referencia nm_mes_referencia  nr_semana_referencia  \
# 0                  8            AGOSTO                    31
# 1                  8            AGOSTO                    31
# 2                  8            AGOSTO                    31
# 3                  8            AGOSTO                    31
# 4                  8            AGOSTO                    31
#
#   nm_dia_semana_referencia  nr_dia_referencia  nr_ano_mes_referencia  \
# 0             QUINTA-FEIRA                  1                 201308
# 1             QUINTA-FEIRA                  1                 201308
# 2             QUINTA-FEIRA                  1                 201308
# 3             QUINTA-FEIRA                  1                 201308
# 4             QUINTA-FEIRA                  1                 201308
#
#    id_tipo_linha cd_tipo_linha    ds_tipo_linha ds_natureza_tipo_linha  \
# 0              1             N  DOMÉSTICA MISTA              DOMÉSTICA
# 1              1             N  DOMÉSTICA MISTA              DOMÉSTICA
# 2              1             N  DOMÉSTICA MISTA              DOMÉSTICA
# 3              1             N  DOMÉSTICA MISTA              DOMÉSTICA
# 4              1             N  DOMÉSTICA MISTA              DOMÉSTICA
#
#   ds_servico_tipo_linha ds_natureza_etapa hr_partida_real dt_partida_real  \
# 0            PASSAGEIRO         DOMÉSTICA        08:27:00      2013-08-01
# 1            PASSAGEIRO         DOMÉSTICA        11:35:00      2013-08-01
# 2            PASSAGEIRO         DOMÉSTICA        22:39:00      2013-08-01
# 3            PASSAGEIRO         DOMÉSTICA        15:37:00      2013-08-01
# 4            PASSAGEIRO         DOMÉSTICA        18:10:00      2013-08-01
#
#    nr_ano_partida_real  nr_semestre_partida_real nm_semestre_partida_real  \
# 0               2013.0                       2.0              2º SEMESTRE
# 1               2013.0                       2.0              2º SEMESTRE
# 2               2013.0                       2.0              2º SEMESTRE
# 3               2013.0                       2.0              2º SEMESTRE
# 4               2013.0                       2.0              2º SEMESTRE
#
#    nr_trimestre_partida_real nm_trimestre_partida_real  nr_mes_partida_real  \
# 0                        3.0              3º TRIMESTRE                  8.0
# 1                        3.0              3º TRIMESTRE                  8.0
# 2                        3.0              3º TRIMESTRE                  8.0
# 3                        3.0              3º TRIMESTRE                  8.0
# 4                        3.0              3º TRIMESTRE                  8.0
#
#   nm_mes_partida_real  nr_semana_partida_real nm_dia_semana_partida_real  \
# 0              AGOSTO                    31.0               QUINTA-FEIRA
# 1              AGOSTO                    31.0               QUINTA-FEIRA
# 2              AGOSTO                    31.0               QUINTA-FEIRA
# 3              AGOSTO                    31.0               QUINTA-FEIRA
# 4              AGOSTO                    31.0               QUINTA-FEIRA
#
#    nr_dia_partida_real  nr_ano_mes_partida_real  id_aerodromo_origem  \
# 0                  1.0                 201308.0                  693
# 1                  1.0                 201308.0                  693
# 2                  1.0                 201308.0                  693
# 3                  1.0                 201308.0                  693
# 4                  1.0                 201308.0                  693
#
#   sg_icao_origem sg_iata_origem nm_aerodromo_origem   nm_municipio_origem  \
# 0           SBCT            CWB         AFONSO PENA  SÃO JOSÉ DOS PINHAIS
# 1           SBCT            CWB         AFONSO PENA  SÃO JOSÉ DOS PINHAIS
# 2           SBCT            CWB         AFONSO PENA  SÃO JOSÉ DOS PINHAIS
# 3           SBCT            CWB         AFONSO PENA  SÃO JOSÉ DOS PINHAIS
# 4           SBCT            CWB         AFONSO PENA  SÃO JOSÉ DOS PINHAIS
#
#   sg_uf_origem nm_regiao_origem nm_pais_origem nm_continente_origem  nr_etapa  \
# 0           PR              SUL         BRASIL       AMÉRICA DO SUL         1
# 1           PR              SUL         BRASIL       AMÉRICA DO SUL         1
# 2           PR              SUL         BRASIL       AMÉRICA DO SUL         1
# 3           PR              SUL         BRASIL       AMÉRICA DO SUL         2
# 4           PR              SUL         BRASIL       AMÉRICA DO SUL         2
#
#   hr_chegada_real dt_chegada_real  nr_ano_chegada_real  \
# 0        09:54:00      2013-08-01               2013.0
# 1        12:38:00      2013-08-01               2013.0
# 2        23:50:00      2013-08-01               2013.0
# 3        16:35:00      2013-08-01               2013.0
# 4        19:31:00      2013-08-01               2013.0
#
#    nr_semestre_chegada_real nm_semestre_chegada_real  \
# 0                       2.0              2º SEMESTRE
# 1                       2.0              2º SEMESTRE
# 2                       2.0              2º SEMESTRE
# 3                       2.0              2º SEMESTRE
# 4                       2.0              2º SEMESTRE
#
#    nr_trimestre_chegada_real nm_trimestre_chegada_real  nr_mes_chegada_real  \
# 0                        3.0              3º TRIMESTRE                  8.0
# 1                        3.0              3º TRIMESTRE                  8.0
# 2                        3.0              3º TRIMESTRE                  8.0
# 3                        3.0              3º TRIMESTRE                  8.0
# 4                        3.0              3º TRIMESTRE                  8.0
#
#   nm_mes_chegada_real  nr_semana_chegada_real nm_dia_semana_chegada_real  \
# 0              AGOSTO                    31.0               QUINTA-FEIRA
# 1              AGOSTO                    31.0               QUINTA-FEIRA
# 2              AGOSTO                    31.0               QUINTA-FEIRA
# 3              AGOSTO                    31.0               QUINTA-FEIRA
# 4              AGOSTO                    31.0               QUINTA-FEIRA
#
#    nr_dia_chegada_real  nr_ano_mes_chegada_real  id_equipamento  \
# 0                  1.0                 201308.0             272
# 1                  1.0                 201308.0             272
# 2                  1.0                 201308.0             271
# 3                  1.0                 201308.0             271
# 4                  1.0                 201308.0             271
#
#   sg_equipamento_icao    ds_modelo ds_matricula  id_aerodromo_destino  \
# 0                E195  EMBRAER 195         AXU                    301
# 1                E195  EMBRAER 195         AXI                    162
# 2                E190  EMBRAER 190         AZA                    162
# 3                E190  EMBRAER 190         AZA                    452
# 4                E190  EMBRAER 190         AZA                    628
#
#   sg_icao_destino sg_iata_destino  \
# 0            SBGR             GRU
# 1            SBKP             VCP
# 2            SBKP             VCP
# 3            SBMG             MGF
# 4            SBRJ             SDU
#
#                           nm_aerodromo_destino nm_municipio_destino  \
# 0  GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO            GUARULHOS
# 1                                    VIRACOPOS             CAMPINAS
# 2                                    VIRACOPOS             CAMPINAS
# 3                           SÍLVIO NAME JÚNIOR              MARINGÁ
# 4                                SANTOS DUMONT       RIO DE JANEIRO
#
#   sg_uf_destino nm_regiao_destino nm_pais_destino nm_continente_destino  \
# 0            SP           SUDESTE          BRASIL        AMÉRICA DO SUL
# 1            SP           SUDESTE          BRASIL        AMÉRICA DO SUL
# 2            SP           SUDESTE          BRASIL        AMÉRICA DO SUL
# 3            PR               SUL          BRASIL        AMÉRICA DO SUL
# 4            RJ           SUDESTE          BRASIL        AMÉRICA DO SUL
#
#    nr_escala_destino  lt_combustivel  nr_assentos_ofertados  kg_payload  \
# 0                NaN          2347.0                  118.0     15505.0
# 1                NaN          2048.0                  118.0     16254.0
# 2                NaN          2059.0                  106.0     15974.0
# 3                NaN          2002.0                  106.0     15624.0
# 4                NaN          2904.0                  106.0     15470.0
#
#    km_distancia  nr_passag_pagos  nr_passag_gratis  kg_bagagem_livre  \
# 0         359.0             75.0               1.0             391.0
# 1         349.0             60.0               2.0             457.0
# 2         349.0             55.0               1.0             385.0
# 3         367.0             55.0               1.0             495.0
# 4         676.0             78.0               1.0             455.0
#
#    kg_bagagem_excesso  kg_carga_paga  kg_carga_gratis  kg_correio  \
# 0                42.0            4.0              0.0         0.0
# 1                68.0          495.0              0.0         0.0
# 2                82.0          188.0              0.0         0.0
# 3                19.0           30.0              0.0         0.0
# 4               124.0           18.0              0.0         0.0
#
#    nr_decolagem nr_horas_voadas  kg_peso nr_velocidade_media  \
# 0             1            1,45   6137.0             247,828
# 1             1            1,05   5670.0             332,153
# 2             1            1,18   4855.0              295,56
# 3             1            0,97   4744.0             377,943
# 4             1            1,35   6522.0              500,56
#
#    nr_pax_gratis_km  nr_carga_paga_km  nr_carga_gratis_km  nr_correio_km  \
# 0             359.0              1436                 0.0            0.0
# 1             698.0            172755                 0.0            0.0
# 2             349.0             65612                 0.0            0.0
# 3             367.0             11010                 0.0            0.0
# 4             676.0             12168                 0.0            0.0
#
#    nr_bagagem_paga_km  nr_bagagem_gratis_km   nr_ask   nr_rpk   nr_atk  \
# 0             15078.0              140369.0  42362.0  26925.0   5566.0
# 1             23732.0              159493.0  41182.0  20940.0   5672.0
# 2             28618.0              134365.0  36994.0  19195.0   5574.0
# 3              6973.0              181665.0  38902.0  20185.0   5734.0
# 4             83824.0              307580.0  71656.0  52728.0  10457.0
#
#    nr_rtk  id_arquivo    nm_arquivo  nr_linha           dt_sistema  nr_chave
# 0  2176.0        8967  AZUAGO13.txt   15843.0  2019-08-25 22:57:15       NaN
# 1  1926.0        8967  AZUAGO13.txt   44539.0  2019-08-25 22:57:15       NaN
# 2  1668.0        8967  AZUAGO13.txt   45470.0  2019-08-25 22:57:15       NaN
# 3  1713.0        8967  AZUAGO13.txt    6760.0  2019-08-25 22:57:15       NaN
# 4  4358.0        8967  AZUAGO13.txt    6875.0  2019-08-25 22:57:15       NaN

# %% [markdown]
# ### Initial inspectation: attribute types, value range, basic statistics

# %%
pd.set_option('display.max_info_columns', 111)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 111 columns):
#  #    Column                      Non-Null Count   Dtype
# ---   ------                      --------------   -----
#  0    id_basica                   150000 non-null  float64
#  1    id_empresa                  150000 non-null  int64
#  2    sg_empresa_icao             150000 non-null  str
#  3    sg_empresa_iata             149530 non-null  str
#  4    nm_empresa                  150000 non-null  str
#  5    nm_pais                     150000 non-null  str
#  6    ds_tipo_empresa             150000 non-null  str
#  7    nr_voo                      150000 non-null  int64
#  8    nr_singular                 150000 non-null  int64
#  9    id_di                       150000 non-null  int64
#  10   cd_di                       150000 non-null  object
#  11   ds_di                       150000 non-null  str
#  12   ds_grupo_di                 150000 non-null  str
#  13   dt_referencia               150000 non-null  str
#  14   nr_ano_referencia           150000 non-null  int64
#  15   nr_semestre_referencia      150000 non-null  int64
#  16   nm_semestre_referencia      150000 non-null  str
#  17   nr_trimestre_referencia     150000 non-null  int64
#  18   nm_trimestre_referencia     150000 non-null  str
#  19   nr_mes_referencia           150000 non-null  int64
#  20   nm_mes_referencia           150000 non-null  str
#  21   nr_semana_referencia        150000 non-null  int64
#  22   nm_dia_semana_referencia    150000 non-null  str
#  23   nr_dia_referencia           150000 non-null  int64
#  24   nr_ano_mes_referencia       150000 non-null  int64
#  25   id_tipo_linha               150000 non-null  int64
#  26   cd_tipo_linha               150000 non-null  str
#  27   ds_tipo_linha               150000 non-null  str
#  28   ds_natureza_tipo_linha      150000 non-null  str
#  29   ds_servico_tipo_linha       150000 non-null  str
#  30   ds_natureza_etapa           150000 non-null  str
#  31   hr_partida_real             150000 non-null  str
#  32   dt_partida_real             150000 non-null  str
#  33   nr_ano_partida_real         150000 non-null  float64
#  34   nr_semestre_partida_real    150000 non-null  float64
#  35   nm_semestre_partida_real    150000 non-null  str
#  36   nr_trimestre_partida_real   150000 non-null  float64
#  37   nm_trimestre_partida_real   150000 non-null  str
#  38   nr_mes_partida_real         150000 non-null  float64
#  39   nm_mes_partida_real         150000 non-null  str
#  40   nr_semana_partida_real      150000 non-null  float64
#  41   nm_dia_semana_partida_real  150000 non-null  str
#  42   nr_dia_partida_real         150000 non-null  float64
#  43   nr_ano_mes_partida_real     150000 non-null  float64
#  44   id_aerodromo_origem         150000 non-null  int64
#  45   sg_icao_origem              150000 non-null  str
#  46   sg_iata_origem              147375 non-null  str
#  47   nm_aerodromo_origem         150000 non-null  str
#  48   nm_municipio_origem         150000 non-null  str
#  49   sg_uf_origem                141687 non-null  str
#  50   nm_regiao_origem            141687 non-null  str
#  51   nm_pais_origem              150000 non-null  str
#  52   nm_continente_origem        150000 non-null  str
#  53   nr_etapa                    150000 non-null  int64
#  54   hr_chegada_real             150000 non-null  str
#  55   dt_chegada_real             150000 non-null  str
#  56   nr_ano_chegada_real         150000 non-null  float64
#  57   nr_semestre_chegada_real    150000 non-null  float64
#  58   nm_semestre_chegada_real    150000 non-null  str
#  59   nr_trimestre_chegada_real   150000 non-null  float64
#  60   nm_trimestre_chegada_real   150000 non-null  str
#  61   nr_mes_chegada_real         150000 non-null  float64
#  62   nm_mes_chegada_real         150000 non-null  str
#  63   nr_semana_chegada_real      150000 non-null  float64
#  64   nm_dia_semana_chegada_real  150000 non-null  str
#  65   nr_dia_chegada_real         150000 non-null  float64
#  66   nr_ano_mes_chegada_real     150000 non-null  float64
#  67   id_equipamento              150000 non-null  int64
#  68   sg_equipamento_icao         150000 non-null  str
#  69   ds_modelo                   150000 non-null  str
#  70   ds_matricula                140097 non-null  str
#  71   id_aerodromo_destino        150000 non-null  int64
#  72   sg_icao_destino             150000 non-null  str
#  73   sg_iata_destino             147366 non-null  str
#  74   nm_aerodromo_destino        150000 non-null  str
#  75   nm_municipio_destino        150000 non-null  str
#  76   sg_uf_destino               141700 non-null  str
#  77   nm_regiao_destino           141700 non-null  str
#  78   nm_pais_destino             150000 non-null  str
#  79   nm_continente_destino       150000 non-null  str
#  80   nr_escala_destino           0 non-null       float64
#  81   lt_combustivel              140418 non-null  float64
#  82   nr_assentos_ofertados       150000 non-null  float64
#  83   kg_payload                  150000 non-null  float64
#  84   km_distancia                149994 non-null  float64
#  85   nr_passag_pagos             150000 non-null  float64
#  86   nr_passag_gratis            150000 non-null  float64
#  87   kg_bagagem_livre            140176 non-null  float64
#  88   kg_bagagem_excesso          140176 non-null  float64
#  89   kg_carga_paga               150000 non-null  float64
#  90   kg_carga_gratis             150000 non-null  float64
#  91   kg_correio                  150000 non-null  float64
#  92   nr_decolagem                150000 non-null  int64
#  93   nr_horas_voadas             150000 non-null  str
#  94   kg_peso                     150000 non-null  float64
#  95   nr_velocidade_media         149994 non-null  str
#  96   nr_pax_gratis_km            149994 non-null  float64
#  97   nr_carga_paga_km            150000 non-null  int64
#  98   nr_carga_gratis_km          149994 non-null  float64
#  99   nr_correio_km               150000 non-null  float64
#  100  nr_bagagem_paga_km          140181 non-null  float64
#  101  nr_bagagem_gratis_km        140181 non-null  float64
#  102  nr_ask                      149994 non-null  float64
#  103  nr_rpk                      150000 non-null  float64
#  104  nr_atk                      149994 non-null  float64
#  105  nr_rtk                      149994 non-null  float64
#  106  id_arquivo                  150000 non-null  int64
#  107  nm_arquivo                  150000 non-null  str
#  108  nr_linha                    150000 non-null  float64
#  109  dt_sistema                  150000 non-null  str
#  110  nr_chave                    0 non-null       float64
# dtypes: float64(39), int64(19), object(1), str(52)
# memory usage: 206.5+ MB

# %%
df.describe()
# Out:
#           id_basica    id_empresa         nr_voo    nr_singular  \
# count  1.500000e+05  1.500000e+05  150000.000000  150000.000000
# mean   1.089811e+07  1.000841e+06    3575.367780     322.277253
# std    1.700733e+06  2.491302e+02    2291.376342     188.641577
# min    9.705115e+06  1.000002e+06       2.000000       0.000000
# 25%    9.916247e+06  1.000854e+06    1653.000000     221.000000
# 50%    1.058107e+07  1.000854e+06    3337.000000     291.000000
# 75%    1.119153e+07  1.001093e+06    5113.000000     362.000000
# max    2.043640e+07  1.001738e+06    9991.000000     999.000000
#
#                id_di  nr_ano_referencia  nr_semestre_referencia  \
# count  150000.000000      150000.000000           150000.000000
# mean        4.079600        2013.375767                1.624233
# std         4.381551           0.484322                0.484322
# min         2.000000        2013.000000                1.000000
# 25%         2.000000        2013.000000                1.000000
# 50%         2.000000        2013.000000                2.000000
# 75%         2.000000        2014.000000                2.000000
# max        15.000000        2014.000000                2.000000
#
#        nr_trimestre_referencia  nr_mes_referencia  nr_semana_referencia  \
# count            150000.000000      150000.000000         150000.000000
# mean                  2.248467           5.369633             21.859520
# std                   0.968644           3.390253             14.745327
# min                   1.000000           1.000000              1.000000
# 25%                   1.000000           1.000000              4.000000
# 50%                   3.000000           8.000000             32.000000
# 75%                   3.000000           8.000000             34.000000
# max                   3.000000           8.000000             35.000000
#
#        nr_dia_referencia  nr_ano_mes_referencia  id_tipo_linha  \
# count      150000.000000          150000.000000  150000.000000
# mean           15.436627          201342.946300       1.407013
# std             8.930363              45.041931       1.437505
# min             1.000000          201308.000000       0.000000
# 25%             8.000000          201308.000000       1.000000
# 50%            15.000000          201308.000000       1.000000
# 75%            23.000000          201401.000000       1.000000
# max            31.000000          201401.000000       8.000000
#
#        nr_ano_partida_real  nr_semestre_partida_real  \
# count        150000.000000             150000.000000
# mean           2013.375767                  1.624227
# std               0.484322                  0.484324
# min            2013.000000                  1.000000
# 25%            2013.000000                  1.000000
# 50%            2013.000000                  2.000000
# 75%            2014.000000                  2.000000
# max            2014.000000                  2.000000
#
#        nr_trimestre_partida_real  nr_mes_partida_real  nr_semana_partida_real  \
# count              150000.000000        150000.000000           150000.000000
# mean                    2.248460             5.369887               21.860993
# std                     0.968642             3.390402               14.745646
# min                     1.000000             1.000000                1.000000
# 25%                     1.000000             1.000000                4.000000
# 50%                     3.000000             8.000000               32.000000
# 75%                     3.000000             8.000000               34.000000
# max                     3.000000             9.000000               36.000000
#
#        nr_dia_partida_real  nr_ano_mes_partida_real  id_aerodromo_origem  \
# count        150000.000000            150000.000000        150000.000000
# mean             15.442267            201342.946553           439.341833
# std               8.928989                45.041834           229.565681
# min               1.000000            201306.000000             4.000000
# 25%               8.000000            201308.000000           230.000000
# 50%              15.000000            201308.000000           445.000000
# 75%              23.000000            201401.000000           633.000000
# max              31.000000            201402.000000          5999.000000
#
#             nr_etapa  nr_ano_chegada_real  nr_semestre_chegada_real  \
# count  150000.000000        150000.000000             150000.000000
# mean        1.275927          2013.375767                  1.624227
# std         0.714764             0.484322                  0.484324
# min         1.000000          2013.000000                  1.000000
# 25%         1.000000          2013.000000                  1.000000
# 50%         1.000000          2013.000000                  2.000000
# 75%         1.000000          2014.000000                  2.000000
# max         8.000000          2014.000000                  2.000000
#
#        nr_trimestre_chegada_real  nr_mes_chegada_real  nr_semana_chegada_real  \
# count              150000.000000        150000.000000           150000.000000
# mean                    2.248460             5.371927               21.871340
# std                     0.968642             3.391042               14.748145
# min                     1.000000             1.000000                1.000000
# 25%                     1.000000             1.000000                4.000000
# 50%                     3.000000             8.000000               32.000000
# 75%                     3.000000             8.000000               34.000000
# max                     3.000000             9.000000               36.000000
#
#        nr_dia_chegada_real  nr_ano_mes_chegada_real  id_equipamento  \
# count        150000.000000            150000.000000   150000.000000
# mean             15.459000            201342.948593       99.088567
# std               8.923574                45.041513       85.291250
# min               1.000000            201306.000000       12.000000
# 25%               8.000000            201308.000000       15.000000
# 50%              15.000000            201308.000000      100.000000
# 75%              23.000000            201401.000000      101.000000
# max              31.000000            201402.000000      368.000000
#
#        id_aerodromo_destino  nr_escala_destino  lt_combustivel  \
# count         150000.000000                0.0   140418.000000
# mean             439.535647                NaN     5070.971428
# std              230.080765                NaN     7934.157899
# min                4.000000                NaN        0.000000
# 25%              233.000000                NaN     2503.000000
# 50%              445.000000                NaN     3586.000000
# 75%              633.000000                NaN     5656.000000
# max             5999.000000                NaN   126955.000000
#
#        nr_assentos_ofertados     kg_payload   km_distancia  nr_passag_pagos  \
# count          150000.000000  150000.000000  149994.000000    150000.000000
# mean              147.554760   18300.459993    1243.341067       108.175467
# std                54.517656   14774.476108    1619.737177        52.196790
# min                 0.000000       0.000000       0.000000         0.000000
# 25%               118.000000   14820.750000     410.000000        73.000000
# 50%               160.000000   16900.000000     739.000000       109.000000
# 75%               183.000000   18595.250000    1452.000000       143.000000
# max               432.000000  550000.000000   12217.000000       432.000000
#
#        nr_passag_gratis  kg_bagagem_livre  kg_bagagem_excesso  kg_carga_paga  \
# count     150000.000000     140176.000000       140176.000000  150000.000000
# mean           2.236800       1328.965800           23.529228     944.881620
# std            3.133476        999.948463           64.314075    5186.199842
# min            0.000000          0.000000            0.000000       0.000000
# 25%            0.000000        631.000000            0.000000       0.000000
# 50%            1.000000       1175.000000            0.000000      21.000000
# 75%            3.000000       1879.000000            6.000000     410.000000
# max          175.000000      15323.000000         3018.000000  131636.000000
#
#        kg_carga_gratis     kg_correio   nr_decolagem        kg_peso  \
# count    150000.000000  150000.000000  150000.000000  150000.000000
# mean          9.981940     170.693267       0.998387   10672.086947
# std          76.520115    1710.727206       0.040134    6900.943664
# min           0.000000       0.000000       0.000000       0.000000
# 25%           0.000000       0.000000       1.000000    6804.000000
# 50%           0.000000       0.000000       1.000000   10062.000000
# 75%           0.000000       0.000000       1.000000   13535.000000
# max       10016.000000   54567.000000       1.000000  131636.000000
#
#        nr_pax_gratis_km  nr_carga_paga_km  nr_carga_gratis_km  nr_correio_km  \
# count      1.499940e+05      1.500000e+05        1.499940e+05   1.500000e+05
# mean       3.291853e+03      4.096039e+06        1.218680e+04   2.331621e+05
# std        1.112945e+04      3.066136e+07        3.712522e+05   2.276238e+06
# min        0.000000e+00      0.000000e+00        0.000000e+00   0.000000e+00
# 25%        0.000000e+00      0.000000e+00        0.000000e+00   0.000000e+00
# 50%        7.340000e+02      1.278550e+04        0.000000e+00   0.000000e+00
# 75%        2.588000e+03      3.375135e+05        0.000000e+00   0.000000e+00
# max        1.681580e+06      9.743250e+08        9.448090e+07   1.433640e+08
#
#        nr_bagagem_paga_km  nr_bagagem_gratis_km        nr_ask        nr_rpk  \
# count        1.401810e+05          1.401810e+05  1.499940e+05  1.500000e+05
# mean         2.135228e+04          1.872641e+06  2.192359e+05  1.712367e+05
# std          8.238368e+04          5.630058e+06  4.241924e+05  3.563972e+05
# min          0.000000e+00          0.000000e+00  0.000000e+00  0.000000e+00
# 25%          0.000000e+00          2.865290e+05  5.570000e+04  3.418800e+04
# 50%          0.000000e+00          7.575700e+05  1.008900e+05  7.151100e+04
# 75%          2.700000e+03          1.886980e+06  2.053260e+05  1.620920e+05
# max          6.340820e+06          1.094570e+08  4.324820e+06  4.263730e+06
#
#              nr_atk         nr_rtk     id_arquivo       nr_linha  nr_chave
# count  1.499940e+05  149994.000000  150000.000000  150000.000000       0.0
# mean   3.407009e+04   19822.746343    9387.605140   31533.931467       NaN
# std    1.006785e+05   51575.098961     493.202043   28278.638177       NaN
# min    0.000000e+00       0.000000    8967.000000       1.000000       NaN
# 25%    6.625000e+03    3147.000000    8979.000000    5792.750000       NaN
# 50%    1.144600e+04    6813.000000    9096.000000   24362.000000       NaN
# 75%    2.282150e+04   15623.000000    9870.000000   51453.250000       NaN
# max    4.534200e+06  974324.000000   15613.000000  102179.000000       NaN

# %% [markdown]
# ### Attribute analysis
#
# 1. Attribute correlations:
#     - *Time correlation:* `dt_referencia`, `nr_ano_referencia`, `nr_mes_referencia`, `nr_dia_referencia`, `nr_ano_mes_referencia`, `nr_semana_referencia`, `nr_trimestre_referencia` - these attributes encode the same date/time at different level of detalization.
#     - *Distance and capacity:* `km_distancia` and `nr_ask`, `nr_rpk`, `nr_atk`, `nr_rtk` - each of these attributes scales with distance; `kg_pesoatis`, `kg_correio`, `kg_bagagem_livre`, `kg_bagagem_excesso`, `nr_passag_pagos`, `nr_passag_gratis` - total aircraft weight is built from those attributes.
#     - *Passangers and load:* `nr_passag_pagos` and `nr_rpk`, `nr_passag_gratis` and `nr_pax_gratis_km`, `kg_carga_paga` and `nr_carga_paga_km`, `kg_carga_gratis` and `nr_carga_gratis_km`, `kg_correio` and `nr_correio_km`, `kg_bagagem_livre` and `nr_bagagem_gratis_km`, `kg_bagagem_excesso` and `nr_bagagem_paga_km` - these pairs of attributes are mathematically linked, since each `*_km` variable is the product of a load/passenger measure and distance.
# 2. Basic statistics analysis and its meaning in business terms:
#
# The dataset contains highly heterogeneous flights. For example, `km_distancia` has standard deviation of 1800 km, which means the data includes both domestic and international flights and therefore reflects different operational contexts.
#
# Passenger-related variables are relatively stable compared to cargo variables: `nr_passag_pagos` is centered around 100 passengers per leg, while `nr_passag_gratis` is much lower, which suggests that most traffic comes from revenue passengers. In contrast, cargo attributes such as `kg_carga_paga` and `kg_correio` are highly skewed, with many zero or small values and a few very large ones, showing that cargo transport is concentrated in a smaller number of flights.
#
# This means that business decisions based on the dataset should not rely only on averages, because the averages hide strong differences between route types, airlines, and flight purposes.
#
# 3. Most relevant attributes according to data mining goal:
#     - `id_basica`: Numeric code identifier of the basic step in the system.
#     - `sg_empresa_icao`: ICAO acronym of the airline.
#     - `dt_partida_real`: Date of realization.
#     - `cd_di`: Character used to identify the type of authorization for each flight stage.
#     - `ds_grupo_di`: Description of the DI group or Flight Type.
#     - `cd_tipo_linha`: Character that identifies the type of line.
#     - `sg_icao_origem`: ICAO acronym of the aerodrome of origin.
#     - `nm_municipio_origem`: Name of the municipality of origin.
#     - `sg_uf_origem`: Acronym of the Federative Unit of origin.
#     - `nm_pais_origem`: Name of the country of origin.
#     - `nm_continente_origem`: Name of the continent of origin.
#     - `sg_icao_destino`: ICAO acronym of the destination airfield.
#     - `nm_municipio_destino`: Name of the destination municipality.
#     - `sg_uf_destino`: Acronym of the destination Federative Unit.
#     - `nm_pais_destino`: Name of the destination country.
#     - `nm_continente_destino`: Name of the destination continent.
#     - `km_distancia`: Distance, expressed in kilometers, between the aerodromes of origin and destination of the stage, considering the curvature of planet earth.
#     - `nr_passag_pagos`: Number of passengers who occupy seats
#     - `nr_passag_gratis`: Number of passengers who occupy seats marketed to the public, but do not generate revenue, with the purchase of seats, for the air transport company.
#     - `nr_rpk`: Refers to the volume of Passenger Kilometers Transported (Revenue Passenger Kilometer). It is calculated, in each basic step, by the product between the number of passengers paid and the distance of the stage.
#     - `nr_ask`: Refers to the volume of Seat Kilometers Offered (Available Seat Kilometer). It is calculated, in each basic step, by the product between the number of seats offered and the distance of the stage.
#     - `nr_carga_paga_km`: Refers to the product between the amount of load paid (kg) and the distance of the basic step (km).
#     - `nr_carga_gratis_km`: Refers to the product between the amount of free load (kg) and the distance of the basic step (km).
#
# 4. Data balancing:
#
# Data balancing is not necessary because our main task is time-series prediction, not classification.

# %% [markdown]
# ## 3. Explore data

# %% [markdown]
# ### Initial hypotheses:
#
# 1. Passenger traffic is seasonal.
# 2. Domestic operations dominate the monthly totals.
# 3. Demand is concentrated in a limited number of airlines and routes.

# %% [markdown]
# ### Basic analysis to verify the hypothesis
#
# #### Seasonal analysis

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df_explore = df.copy()

# get date attribute
date_col = 'dt_partida_real' if 'dt_partida_real' in df_explore.columns else 'dt_referencia'
df_explore[date_col] = pd.to_datetime(df_explore[date_col], errors='coerce')

# get total number of passengers
df_explore['total_passengers'] = (df_explore['nr_passag_pagos'].fillna(0) + df_explore['nr_passag_gratis'].fillna(0))

# create monthly timestamp for aggregation
df_explore['year_month'] = df_explore[date_col].dt.to_period('M').dt.to_timestamp()

# %%
monthly_traffic = (
    df_explore.dropna(subset=['year_month'])
    .groupby('year_month', as_index=False)
    .agg(
        total_passengers=('total_passengers', 'sum'),
        paid_passengers=('nr_passag_pagos', 'sum'),
        free_passengers=('nr_passag_gratis', 'sum'),
        flights=('id_basica', 'count')
    )
    .sort_values('year_month')
)

monthly_traffic['rolling_12m'] = monthly_traffic['total_passengers'].rolling(window=12, min_periods=1).mean()

fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(monthly_traffic['year_month'], monthly_traffic['total_passengers'], label='Monthly total passengers')
ax.plot(monthly_traffic['year_month'], monthly_traffic['rolling_12m'], label='12-month rolling mean')

ax.set_title('Monthly passenger traffic')
ax.set_xlabel('Month')
ax.set_ylabel('Passengers')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
monthly_traffic.head()
# Out:
#   year_month  total_passengers  paid_passengers  free_passengers  flights  \
# 0 2013-06-01              20.0             20.0              0.0        1
# 1 2013-07-01             251.0            251.0              0.0        3
# 2 2013-08-01         9731270.0        9534300.0         196970.0    93595
# 3 2013-09-01            3987.0           3940.0             47.0       36
# 4 2014-01-01         6825747.0        6687257.0         138490.0    56358
#
#    rolling_12m
# 0         20.0
# 1        135.5
# 2    3243847.0
# 3    2433882.0
# 4    3312255.0

# %% [markdown]
# #### Sub-population analysis

# %%
# Domestic vs international flights

nature_col = 'ds_natureza_tipo_linha' if 'ds_natureza_tipo_linha' in df_explore.columns else None
if nature_col is not None:
    nature_summary = (
        df_explore.groupby(nature_col)['total_passengers']
        .sum()
        .sort_values(ascending=False)
    )
    display(nature_summary.to_frame('total_passengers'))

    fig, ax = plt.subplots(figsize=(8, 4))
    ax.bar(nature_summary.index.astype(str), nature_summary.values)
    ax.set_title('Passenger volume by flight nature')
    ax.set_xlabel('Flight nature')
    ax.set_ylabel('Passengers')
    ax.grid(axis='y', alpha=0.3)
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.show()
# Out:
#                         total_passengers
# ds_natureza_tipo_linha
# DOMÉSTICA                     14303878.0
# NÃO IDENTIFICADA               1362337.0
# INTERNACIONAL                   895625.0

# %%
# Top airlines by total passengers

top_airlines = (
    df_explore.groupby('nm_empresa')['total_passengers']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

display(top_airlines.to_frame('total_passengers'))

fig, ax = plt.subplots(figsize=(10, 5))
ax.barh(top_airlines.index[::-1].astype(str), top_airlines.values[::-1])
ax.set_title('Top 10 airlines by passenger volume')
ax.set_xlabel('Passengers')
ax.set_ylabel('Airline')
ax.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#                                                     total_passengers
# nm_empresa
# GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS S...         6647896.0
# TAM LINHAS AÉREAS S.A.                                     5061690.0
# AZUL LINHAS AÉREAS BRASILEIRAS S/A                         1616840.0
# OCEANAIR LINHAS AÉREAS S.A. (AVIANCA)                      1135131.0
# TRIP SERVIÇOS DE SUPORTE AÉREO S.A (EX. TRIP LI...          501067.0
# AMERICAN AIRLINES, INC.                                     159434.0
# COMPAÑIA PANAMEÑA DE AVIACION S.A. (COPA AIRLINES)          157493.0
# PASSAREDO TRANSPORTES AÉREOS S.A.                           151646.0
# TAP - TRANSPORTES AÉREOS PORTUGUESES S/A                    150174.0
# UNITED AIRLINES, INC                                         66739.0

# %% [markdown]
# ### Inference
#
# Since the analysis was performed only on the sample data, the hypotheses cannot be considered fully confirmed. But since it is supported by positive experimental results, they can orient us in further analysis.

# %% [markdown]
# ## 4. Verify data quality
